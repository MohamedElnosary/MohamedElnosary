# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/55025843-7d99a280-4fe0-11e9-938a-4879d95c4130.png"
#     style="width:150px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Python in under 10 minutes
#
# Ok, so this will techincally take us more than 10 minutes, but you get the idea: this is a very high level overview of the Python programming language. Specially for those of you that already know some other programming language (R, Javascript, Ruby, etc) and want to do the switch to Python.
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Manually reconstruct the data from the provided text table
data = {
    "Ligands": [
        "C. albicans.1EAG",
        "B. subtilis.5NXYB",
        "S. aureus.1MWT",
        "E. coli.1BTLE",
        "K. pneumoniae.4HL2 E"
    ],
    "Apigenin": [-7.5, -4.4, -8.3, -7.6, -5],
    "Caffeicacid": [-5.8, -3.7, -6.4, -6, -4.4],
    "Catechin": [-7.3, -4.5, -8.1, -7.8, -5],
    "Chlorogenicacid": [-7.5, -4.6, -8, -7.3, -5],
    "Chrysin": [-7.6, -4.5, -8.3, -7, -5.1],
    "Cinnamicacid": [-5.6, -3.5, -6.1, -5.9, -4.1],
    "Epicatechin": [-7.3, -4.5, -7.9, -7.7, -5.3],
    "Gallicacid": [-5.1, -3.9, -6.4, -5.5, -4.2],
    "Kaempferol": [-7.5, -4.3, -8.1, -7.2, -5.3],
    "p-coumaric": [-5.6, -3.3, -6.2, -5.7, -4.2],
    "p-hydroxybenzoicacid": [-4.9, -3.3, -5.8, -5.2, -4],
    "Protocatechuic": [-5.1, -3.7, -6.3, -5.2, -4.3],
    "Quercetin": [-7.5, -4.5, -8.6, -7.5, -5.3],
    "Rutin": [-8.2, -2.4, -8.9, -6.5, -4.1],
    "Sinapicacid": [-5.4, -3.6, -6.2, -5.8, -4.1],
    "Syringicacid": [-5.1, -3.4, -5.9, -5.6, -4.2],
    "Vanillicacid": [-5.1, -3.4, -6.1, -5.7, -4.4],
    "Meropenem.antibiotic": [0, 0, 0, 0, -5.3],
    "Clavulanic.acid.antibiotic": [0, 0, 0, -5.8, 0],
    "Ceftaroline.antibiotic": [0, 0, -6.5, 0, 0],
    "Ampicillin.antibiotic": [0, -4.3, 0, 0, 0],
    "Pepstatin.A.antifungal": [-7.1, 0, 0, 0, 0]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)

# Plot heatmap
plt.figure(figsize=(14, 6))
sns.heatmap(df, annot=False, cmap="coolwarm", center=0)
plt.xlabel("Ligands")
plt.ylabel("Microoraganism")
plt.title("Affinity score (Kcal.mol-1) ")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# إنشاء البيانات
data = {
    "Ligands": [
        "Apigenin", "Caffeicacid", "Catechin", "Chlorogenicacid", "Chrysin", "Cinnamicacid",
        "Epicatechin", "Gallicacid", "Gentisicacid", "Kaempferol", "p-coumaric", "p-hydroxybenzoicacid",
        "Protocatechuic", "Quercetin", "Rutin", "Sinapicacid", "Syringicacid", "Vanillicacid",
        "Meropenem.antibiotic", "Clavulanic acid.antibiotic", "Ceftaroline.antibiotic",
        "Ampicillin.antibiotic", "Pepstatin.A.antifungal"
    ],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, 0, 0, 0, 0],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, 0, -5.8, 0, 0, 0],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, 0, 0, -6.5, 0, 0],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, 0, 0, 0, -4.3, 0],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, 0, 0, 0, 0, -7.1]
}

# تحويل ل DataFrame
df = pd.DataFrame(data)

# جعل Ligands كمؤشر
df.set_index("Ligands", inplace=True)

# رسم Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df, annot=True, cmap="coolwarm", cbar_kws={'label': 'Binding Energy'})

# كتابة العناوين
plt.xlabel("Microorganism", fontsize=14)
plt.ylabel("Ligands", fontsize=14)
plt.title("Heatmap of Ligand Binding Energies", fontsize=16)

# عرض الرسم
plt.show()

# %% [markdown]
# ### The high level
#
# [Python](https://en.wikipedia.org/wiki/Python_%28programming_language%29) is a interpreted, high level programming language created by Dutch programmer [Guido van Rossum](https://en.wikipedia.org/wiki/Guido_van_Rossum) and released in 1991.
#
# As I always say, Python *is old*. It gained a lot of traction around 2006, with its popularity being driven its beauty and simplicity to do Web Development (its main Web Development Framework, [Django](https://www.djangoproject.com/), was released in 2006). From there, it took off as one of the most popular scripting languages.
#
# Python is multi-paradigm: you can write code using Object Oriented, Functional and/or Imperative programming. Python is interpreted and uses a dynamic type system, although considered _strongly typed_.
#
# It has an extensive builtin standard library with features that ranges from time management, to http servers, concurrency and async programming.
#
# Python is Open Source and is managed by a non-profit organization: the [Python Software Foundation](https://en.wikipedia.org/wiki/Python_Software_Foundation).
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Python 3 vs Python 2
#
# You might have heard that there are two main versions of Python around: _Python 2_ and _Python 3_. Well, I'll keep it simple for you:
#
# ### 👍 Python 3: YES!
# ### 🙅 Python 2: NO!
#
# Python 2 [will be deprecated in 2020](https://pythonclock.org/). So **stick to Python 3**, it's the present and the future of the language (at least until we start planning Python 4 😅, just kidding).
#
# ## A quick note about different "implementations"
#
# Finally, all what I'm saying here technically applies to "CPython", Python's main _implementation_. Don't worry if this doesn't make sense. It's just for the curious ones. If you're interested, we've written an entire post about it: [A quick guide about Python implementations](https://blog.rmotr.com/a-quick-guide-about-python-implementations-aa224109f321).
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# # Syntax Overview
#
# The following paragraphs will be dedicated to Python's syntax and technical details. There are more to Python than just syntax, as its community, events, email lists, etc. But after all, this is just a technical introduction.
#
# ### Indentation based
#
# This might feel weird at first, but in Python we do NOT use curly braces to denote blocks of code. We use _"indentation"_ instead. This is similar to Ruby. For example, this is a very simple `add_numbers` function in javascript:
#
# ```javascript
# function add_numbers(x, y){
#     return x + y
# }
# ```
#
# In Python, we'd write it in this way:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# البيانات
data = {
    "Ligands": [
        # Plant bioactive compounds
        "Apigenin", "Caffeicacid", "Catechin", "Chlorogenicacid", "Chrysin", "Cinnamicacid",
        "Epicatechin", "Gallicacid", "Gentisicacid", "Kaempferol", "p-coumaric", "p-hydroxybenzoicacid",
        "Protocatechuic", "Quercetin", "Rutin", "Sinapicacid", "Syringicacid", "Vanillicacid",
        # Antibiotics
        "Meropenem.antibiotic", "Clavulanic acid.antibiotic", "Ceftaroline.antibiotic", "Ampicillin.antibiotic",
        # Antifungal
        "Pepstatin.A.antifungal"
    ],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, 0, 0, 0, 0],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, 0, -5.8, 0, 0, 0],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, 0, 0, -6.5, 0, 0],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, 0, 0, 0, -4.3, 0],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, 0, 0, 0, 0, -7.1]
}

# تحويل ل DataFrame
df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)

# استبدال القيم الفارغة بـ 0
df = df.fillna(0)

# رسم clustermap
g = sns.clustermap(
    df,
    cmap="coolwarm",
    annot=True,
    fmt=".1f",
    linewidths=0.5,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10)
)

# تعديل العناوين
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)
g.ax_heatmap.set_title("Heatmap with Clustering", fontsize=16)

plt.show()

# %%
def add_numbers(x, y):
    return x + y

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# البيانات
data = {
    "Ligands": [
        # Plant bioactive compounds
        "Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
        "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric", "p-hydroxybenzoic acid",
        "Protocatechuic", "Quercetin", "Rutin", "Sinapicacid", "Syringicacid", "Vanillicacid",
        # Antibiotics
        "Meropenem", "Clavulanic acid", "Ceftaroline", "Ampicillin",
        # Antifungal
        "Pepstatin A"
    ],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, 0, 0, 0, 0],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, 0, -5.8, 0, 0, 0],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, 0, 0, -6.5, 0, 0],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, 0, 0, 0, -4.3, 0],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, 0, 0, 0, 0, -7.1]
}

# تحويل ل DataFrame
df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)

# استبدال القيم الفارغة بـ 0
df = df.fillna(0)

# -------------------------
# ألوان الأعمدة (تصنيف الميكروبات)
col_colors = [
    "#ADD8E6",  # Gram positive (K. pneumoniae)
    "#FFA07A",  # Gram negative (E. coli)
    "#ADD8E6",  # Gram positive (S. aureus)
    "#FFA07A",  # Gram negative (B. subtilis)
    "#D8BFD8"   # Fungi (C. albicans)
]

# ألوان الصفوف (تصنيف المركبات)
row_colors = []
for ligand in df.index:
    if "antibiotic" in ligand.lower():
        row_colors.append("#FFB6C1")  # أحمر فاتح
    elif "antifungal" in ligand.lower():
        row_colors.append("#D3D3D3")  # رمادي فاتح
    else:
        row_colors.append("#90EE90")  # أخضر فاتح

# -------------------------
# رسم clustermap
g = sns.clustermap(
    df,
    cmap="coolwarm",
    annot=True,
    fmt=".1f",
    linewidths=0.5,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    col_colors=col_colors,
    row_colors=row_colors
)

# تعديل العناوين
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)
g.ax_heatmap.set_title("Heatmap with Clustering and Category Colors", fontsize=16)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem (antibiotic)", "Clavulanic acid (antibiotic)",
                "Ceftaroline (antibiotic)", "Ampicillin (antibiotic)", "Pepstatin A (antifungal)"],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)

# تعويض القيم الفارغة بـ 0 أو متوسط القيم
df = df.fillna(0)

# رسم clustermap
sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.5,
    annot=False,  # منع ظهور الأرقام
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    col_colors=col_colors,
    row_colors=row_colors
)

plt.suptitle("Grame positive bacteria | Grame negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem (antibiotic)", "Clavulanic acid (antibiotic)",
                "Ceftaroline (antibiotic)", "Ampicillin (antibiotic)", "Pepstatin A (antifungal)"],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)
df = df.fillna(0)

# ألوان افتراضية بسيطة لتجنب الخطأ
col_colors = None
row_colors = None

# رسم clustermap
g = sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.5,
    annot=False,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    col_colors=col_colors,
    row_colors=row_colors
)

# تسمية المحاور
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)

# جعل أسماء Microorganisms بخط مائل
for label in g.ax_heatmap.get_xticklabels():
    label.set_fontstyle('italic')

plt.suptitle("Gram positive bacteria | Gram negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem (antibiotic)", "Clavulanic acid (antibiotic)",
                "Ceftaroline (antibiotic)", "Ampicillin (antibiotic)", "Pepstatin A (antifungal)"],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)
df = df.fillna(0)

# ألوان افتراضية لتجنب الخطأ
col_colors = None
row_colors = None

# رسم clustermap
g = sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.5,
    annot=False,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    col_colors=col_colors,
    row_colors=row_colors
)

# تسمية المحاور
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)

# جعل أسماء Microorganisms بخط مائل
for label in g.ax_heatmap.get_xticklabels():
    label.set_fontstyle('italic')

# إضافة legend مخصص للمجموعات
antibiotics_patch = mpatches.Patch(color="red", label="Antibiotics")
antifungal_patch = mpatches.Patch(color="blue", label="Antifungal")
plant_patch = mpatches.Patch(color="green", label="Plant active")

plt.legend(handles=[antibiotics_patch, antifungal_patch, plant_patch],
           title="Compound Category",
           bbox_to_anchor=(1.05, 1), loc='upper left')

plt.suptitle("Gram positive bacteria | Gram negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
plt.show()

# %% [markdown]
# An `if-else` block in Javascript:
#
# ```javascript
# let language = "Python"
#
# if (language === "Python"){
#     console.log("Let the fun begin");
# } else {
#     console.log("You sure?");
# }
# ```
#
# In Python:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem (antibiotic)", "Clavulanic acid (antibiotic)",
                "Ceftaroline (antibiotic)", "Ampicillin (antibiotic)", "Pepstatin A (antifungal)"],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)
df = df.fillna(0)

# تحديد ألوان التصنيف
ligand_colors = []
for ligand in df.index:
    if "(antibiotic)" in ligand.lower():
        ligand_colors.append("red")
    elif "(antifungal)" in ligand.lower():
        ligand_colors.append("blue")
    else:
        ligand_colors.append("green")

# رسم clustermap
g = sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.5,
    annot=False,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    row_colors=ligand_colors
)

# تسمية المحاور
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)

# جعل أسماء Microorganisms بخط مائل
for label in g.ax_heatmap.get_xticklabels():
    label.set_fontstyle('italic')

# إضافة legend للتصنيفات
antibiotics_patch = mpatches.Patch(color="red", label="Antibiotics")
antifungal_patch = mpatches.Patch(color="blue", label="Antifungal")
plant_patch = mpatches.Patch(color="green", label="Plant active")

plt.legend(handles=[plant_patch, antibiotics_patch, antifungal_patch],
           title="Compound Category",
           bbox_to_anchor=(1.25, 1), loc='upper left')

plt.suptitle("Gram positive bacteria | Gram negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem (antibiotic)", "Clavulanic acid (antibiotic)",
                "Ceftaroline (antibiotic)", "Ampicillin (antibiotic)", "Pepstatin A (antifungal)"],
    "K. pneumoniae (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)
df = df.fillna(0)

# تحديد ألوان Ligands
ligand_colors = []
for ligand in df.index:
    if "(antibiotic)" in ligand.lower():
        ligand_colors.append("red")
    elif "(antifungal)" in ligand.lower():
        ligand_colors.append("blue")
    else:
        ligand_colors.append("green")

# تحديد ألوان Microorganisms
microbe_colors = []
for microbe in df.columns:
    if "k. pneumoniae" in microbe.lower() or "e. coli" in microbe.lower():
        microbe_colors.append("orange")  # Gram negative
    elif "s. aureus" in microbe.lower() or "b. subtilis" in microbe.lower():
        microbe_colors.append("purple")  # Gram positive
    elif "c. albicans" in microbe.lower():
        microbe_colors.append("brown")   # Fungi
    else:
        microbe_colors.append("grey")    # أي شيء آخر

# رسم clustermap مع highlights
g = sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.5,
    annot=False,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy'},
    figsize=(12, 10),
    row_colors=ligand_colors,
    col_colors=microbe_colors
)

# تسمية المحاور
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)

# جعل أسماء Microorganisms بخط مائل
for label in g.ax_heatmap.get_xticklabels():
    label.set_fontstyle('italic')

# Legend لتصنيف Ligands
plant_patch = mpatches.Patch(color="green", label="Plant active")
antibiotics_patch = mpatches.Patch(color="red", label="Antibiotics")
antifungal_patch = mpatches.Patch(color="blue", label="Antifungal")

# Legend لتصنيف Microorganisms
gram_neg_patch = mpatches.Patch(color="orange", label="Gram negative")
gram_pos_patch = mpatches.Patch(color="purple", label="Gram positive")
fungi_patch = mpatches.Patch(color="brown", label="Fungi")

plt.legend(
    handles=[plant_patch, antibiotics_patch, antifungal_patch,
             gram_neg_patch, gram_pos_patch, fungi_patch],
    title="Category",
    bbox_to_anchor=(1.25, 1), loc='upper left'
)

plt.suptitle("Gram positive bacteria | Gram negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# البيانات
data = {
    "Ligands": ["Apigenin", "Caffeicacid", "Catechin", "Chlorogenic acid", "Chrysin", "Cinnamic acid",
                "Epicatechin", "Gallic acid", "Gentisic acid", "Kaempferol", "p-coumaric",
                "p-hydroxybenzoic acid", "Protocatechuic", "Quercetin", "Rutin", "Sinapic acid",
                "Syringic acid", "Vanillic acid", "Meropenem ", "Clavulanic acid ",
                "Ceftaroline ", "Ampicillin ", "Pepstatin A "],
    "K. pneumoniae\n (4HL2 E)": [-5, -4.4, -5, -5, -5.1, -4.1, -5.3, -4.2, -7.2, -5.3, -4.2, -4, -4.3, -5.3, -4.1, -4.1, -4.2, -4.4, -5.3, np.nan, np.nan, np.nan, np.nan],
    "E. coli\n (1BTLE)": [-7.6, -6, -7.8, -7.3, -7, -5.9, -7.7, -5.5, -3.1, -7.2, -5.7, -5.2, -5.2, -7.5, -6.5, -5.8, -5.6, -5.7, np.nan, -5.8, np.nan, np.nan, np.nan],
    "S. aureus\n (1MWT)": [-8.3, -6.4, -8.1, -8, -8.3, -6.1, -7.9, -6.4, -6.7, -8.1, -6.2, -5.8, -6.3, -8.6, -8.9, -6.2, -5.9, -6.1, np.nan, np.nan, -6.5, np.nan, np.nan],
    "B. subtilis (5NXYB)": [-4.4, -3.7, -4.5, -4.6, -4.5, -3.5, -4.5, -3.9, -5.2, -4.3, -3.3, -3.3, -3.7, -4.5, -2.4, -3.6, -3.4, -3.4, np.nan, np.nan, np.nan, -4.3, np.nan],
    "C. albicans\n (1EAG)": [-7.5, -5.8, -7.3, -7.5, -7.6, -5.6, -7.3, -5.1, -4.1, -7.5, -5.6, -4.9, -5.1, -7.5, -8.2, -5.4, -5.1, -5.1, np.nan, np.nan, np.nan, np.nan, -7.1]
}

df = pd.DataFrame(data)
df.set_index("Ligands", inplace=True)
df = df.fillna(0)

# تحديد ألوان Ligands
ligand_colors = []
for ligand in df.index:
    if "(antibiotic)" in ligand.lower():
        ligand_colors.append("red")
    elif "(antifungal)" in ligand.lower():
        ligand_colors.append("blue")
    else:
        ligand_colors.append("green")

# تحديد ألوان Microorganisms
microbe_colors = []
for microbe in df.columns:
    if "k. pneumoniae" in microbe.lower() or "e. coli" in microbe.lower():
        microbe_colors.append("orange")  # Gram negative
    elif "s. aureus" in microbe.lower() or "b. subtilis" in microbe.lower():
        microbe_colors.append("purple")  # Gram positive
    elif "c. albicans" in microbe.lower():
        microbe_colors.append("brown")   # Fungi
    else:
        microbe_colors.append("grey")    # أي شيء آخر

# رسم clustermap مع highlights
g = sns.clustermap(
    df,
    cmap="coolwarm",
    linewidths=0.1,
    annot=False,
    col_cluster=True,
    row_cluster=True,
    cbar_kws={'label': 'Binding Energy\n(Kcal.mol-1)'},
    figsize=(12, 10),
    row_colors=ligand_colors,
    col_colors=microbe_colors
)

# تسمية المحاور
g.ax_heatmap.set_xlabel("Microorganism", fontsize=14)
g.ax_heatmap.set_ylabel("Ligands", fontsize=14)

# جعل أسماء Microorganisms بخط مائل
for label in g.ax_heatmap.get_xticklabels():
    label.set_fontstyle('italic')

# Legend لتصنيف Ligands
plant_patch = mpatches.Patch(color="green", label="Plant bioactive compunds")
antibiotics_patch = mpatches.Patch(color="red", label="Antibiotics")
antifungal_patch = mpatches.Patch(color="blue", label="Antifungal")

# Legend لتصنيف Microorganisms
gram_neg_patch = mpatches.Patch(color="orange", label="Gram negative bacteria")
gram_pos_patch = mpatches.Patch(color="purple", label="Gram positive bacteria")
fungi_patch = mpatches.Patch(color="brown", label="Fungi")

# عرض الـ legend على يمين الرسم
leg = plt.legend(
    handles=[plant_patch, antibiotics_patch, antifungal_patch,
             gram_neg_patch, gram_pos_patch, fungi_patch],
    title="Category",
    bbox_to_anchor=(15.7, 1), loc='upper left'
)
plt.gca().add_artist(leg)

plt.suptitle("Gram positive bacteria | Gram negative bacteria | Plant bioactive compounds | Antibiotics", y=1.02)
plt.show()

# %%
# try changing "Python" to something else.
# Don't remove the quotes.
language = "Python"

if language == "Python":
    print("Let the fun begin!")
else:
    print("You sure?")

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Comments
#
# You've seen comments in the previous block of code: they're prefixed with a pound/hashtag sign:

# %%
# this is a comment

# %%
# it doesn't produce any output

# %%
# can be above...
print("Hello World")  # next to...
# or below your code

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Variables
#
# We've defined a variable `language` in one of our previous examples. In Python, you can set a variable at any time, in any block of code, by just assigning a valid name to any value you want:

# %%
name = "Mary"
print(name)

# %%
age = 30
print(age)

# %% [markdown]
# Variables, once set, will be preserved:

# %%
print(name, "is", age, "years old")

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Data Types
#
# Python supports the most common data types, the usual suspects we could say:
#
# #### Integers, type `int`:
#
# Integers have unlimited magnitude.

# %%
# an int
age = 30

# %%
age

# %%
type(age)

# %% [markdown]
# #### Floats, type `float`:
#
# The standard floating point number

# %%
# a float
price = 2.50

# %%
price

# %%
type(price)

# %% [markdown]
# Remember that floats sometimes exhibit "extraneous" behavior:

# %%
0.1 * 3

# %% [markdown]
# If you need decimal fixed point precision, you can use the [`decimal`](https://docs.python.org/3/library/decimal.html#module-decimal) module:

# %%
from decimal import Decimal

# %%
Decimal('0.1') * 3

# %% [markdown]
# #### Strings, type `str`
#
# Strings are used to store text. Technically, they're _"immutable sequences of Unicode code points"_. Which means that Python supports Unicode:

# %%
# Create them with double quotes:
print("Hello unicode 👋")

# %%
# single quotes:
print('Omelette Du Fromage 🧀')

# %%
type('Hello World')

# %%
len("Hello")

# %% [markdown]
# You can use double or single quotes, it's the same. We also have "multi-line" strings, that are created with a pair of 3 quotes (simple or double, either works):

# %%
joke = """
Me: What’s the best thing about Switzerland?
Friend: I don't know. What?
Me: I don’t know, but the flag is a big plus.
F: 😒
"""

print(joke)

# %% [markdown]
# #### Booleans, type `bool`
#
# Python booleans are as simple as they get: `True` and `False`, **capitalized**.

# %%
True

# %%
type(False)

# %% [markdown]
# #### None, type `NoneType`
#
# As other languages have `null`, in Python we have `None`, which pretty much represents the absence of value:

# %%
x = None

# %%
x

# %%
print(x)

# %%
type(None)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### `int`, `float`, `str` and `bool` objects and functions
#
# You'll often see some of these _"keywords/names"_ used both as functions and as individual objects. When used as functions, their usage is to transform/cast objects into its corresponding type. Example:

# %%
age_as_string = "28"

# %%
type(age_as_string)

# %%
int(age_as_string)

# %%
age = int(age_as_string)

# %%
type(age)

# %% [markdown]
# Their use as objects is mainly associated with their type:

# %%
type(13) == int

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Functions
#
# We've seen a couple of functions defined already, but let's dig a little bit deeper. Functions in Python are very intuitive. Let's start with an example of a function without parameters:

# %%
def hello():
    return "Hello World"

# %% [markdown]
# The `def` keyword indicate the _definition_ of a function, followed by a name and a list of arguments (which this function doesn't receive). The `return` statement is used to break the flow of the function and return a value back to the caller:

# %%
result = hello()

# %%
result

# %% [markdown]
# If a function doesn't explicitly include a `return` statement, Python will return `None` by default:

# %%
def empty():
    x = 3

# %%
result = empty()

# %%
print(result)

# %% [markdown]
# #### Receiving parameters
#
# There's a lot that can be done with Python parameters; including default and named parameters, and even variable/dynamic ones. But for now, we'll just focus on the basics. Function parameters are listed at the function definition, and they're part of the function's local scope:

# %%
def add(x, y):
    return x + y

# %%
add(2, 3)

# %% [markdown]
# We can also define functions that accept variable number of arguments, using the star args `*`:

# %%
def add(*args):
    return sum(args)

# %%
add(1, 1, 1)

# %%
add(1)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Operators
#
# Both arithmetic and boolean operators are available, for example:
#
# #### Arithmetic operators

# %%
3 + 3

# %%
11 % 7

# %%
2 ** 4

# %% [markdown]
# Precedence can be consulted on [the official docs](https://docs.python.org/3/reference/expressions.html#operator-precedence). But, for the most part, the precedence is similar to the usual in arithmetic:

# %%
3 + 4 * 5

# %%
3 + 4 * 2**3

# %% [markdown]
# #### Boolean operators
#
# Regular comparison operators are available:

# %%
7 > 3

# %%
8 >= 8

# %% [markdown]
# We said that Python is strongly typed, so comparison between different types will fail if these types are not compatible:

# %%
8 > "abc"

# %% [markdown]
# Python also has other common boolean operators like `and`, `or`, `not`, etc. They are short circuited, as most modern programming languages:

# %%
True and True

# %%
not False

# %%
False or True

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Control Flow
#
# Python supports the most common control flow blocks. Keep in mind they're defined with indentation.
#
# #### If/else/elif statements

# %%
days_subscribed = 28

# %%
if days_subscribed >= 30:
    print("Loyal customer")
elif days_subscribed >= 15:
    print("Halfway there")
elif days_subscribed >= 1:
    print("Building confidence")
else:
    print("Too early")

# %% [markdown]
# #### For loops
#
# For loops in Python are different than other languages, specially those C/Java-inspired languages. In Python, `for` loops are designed to iterate over collections (we'll see collections later). But keep that in mind.

# %%
names = ['Monica', 'Ross', 'Chandler', 'Joey', 'Rachel']

# %%
for name in names:
    print(name)

# %% [markdown]
# #### While loops
#
# While loops are seldom used in Python. For loops are the preferred choice 99% of the time. Still, they're available and are useful for some situations:

# %%
count = 0

# %%
while count < 3:
    print("Counting...")
    count += 1

# %% [markdown]
# There's another block to mention, `try/except`, but it's in the **_Exceptions_** section.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Collections
#
# Python has multiple versatile collection types, each with different features and capabilities. These are the most common collections we'll explore:
#
# * Lists
# * Tuples
# * Dictionaries
# * Sets
#
# Even though they all have different capabilities, there is one common property to all of them, and it's that Python collections are heterogeneous, that is, you can mix multiple types. That **doesn't mean we should** mix types, usually it's better to have a consistent collection. But it's still possible.
#
# #### Lists
#
# Lists are mutable, ordered sequences. We could argue, the most common collection type.

# %%
l = [3, 'Hello World', True]

# %%
len(l)

# %% [markdown]
# List elements are accessed using sequential indices (starting from `0`):

# %%
l[0]

# %%
l[1]

# %% [markdown]
# Negative indices are also supported:

# %%
l[-1]

# %%
l[-2]

# %% [markdown]
# Lists have many useful methods to add/remove elements:

# %%
l.append('Python 🐍')

# %%
l

# %%
'Python 🐍' in l

# %%
'Ruby ♦️' in l

# %% [markdown]
# #### Tuples
#
# Tuples are very similar to lists, but with a huge difference: **they're immutable**. That means, once a tuple is created, it can't be further modified:

# %%
t = (3, 'Hello World', True)

# %% [markdown]
# Indexing them works in the same way:

# %%
t[0]

# %%
t[-1]

# %%
'Hello World' in t

# %% [markdown]
# But there's no way of modifying them.

# %% [markdown]
# #### Dictionaries
#
# Dictionaries are map-like collections that store values under a user-defined key. The key must be an immutable object; we usually employ strings for keys. Dictionaries are mutable, and more importantly, **unordered**.

# %%
user = {
    "name": "Mary Smith",
    "email": "mary@example.com",
    "age": 30,
    "subscribed": True
}

# %%
user

# %% [markdown]
# Access is by key, also using square brackets:

# %%
user['email']

# %%
'age' in user

# %%
'last_name' in user

# %% [markdown]
# #### Sets
#
# Sets are unordered collection which the unique characteristic that they only contain unique elements:

# %%
s = {3, 1, 3, 7, 9, 1, 3, 1}

# %%
s

# %% [markdown]
# Adding elements is done with the `add` method:

# %%
s.add(10)

# %% [markdown]
# Removing elements can be done with `pop()`:

# %%
s.pop()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Iterating collections
#
# As mentioned in the control flow section, Python's `for` loop is specially designed to iterate over collections:

# %%
l = [3, 'Hello World', True]

# %%
for elem in l:
    print(elem)

# %%
for key in user:
    print(key.title(), '=>', user[key])

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Modules
#
# One of the best features of Python as a language, is its rich builtin library. To use external modules, you must first import them:

# %%
import random

# %%
random.randint(0, 99)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Exceptions
#
# Exceptions are raised at runtime when an abnormal situation is produced in your program. Exceptions can also be constructed and raised by your code. Example of an exception:

# %%
age = "30"

# %%
if age > 21:
    print("Allowed entrance")

# %% [markdown]
# Exceptions can be handled at runtime with a `try/except` block:

# %%
try:
    if age > 21:
        print("Allowed entrance")
except:
    print("Something went wrong")

# %% [markdown]
# The `except` portion can receive also be parametrized with the expected exception:

# %%
try:
    if age > 21:
        print("Allowed entrance")
except TypeError:
    print("Age is probably of a wrong type")

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## We're just getting started
#
# As you can imagine, there's a lot more to add about such a versatile and powerful language as Python. We're still missing many important topics like _OOP_, _File Management_, _Networking_, _Concurrency_, etc.
#
# If you're eager to learn more about Python, we've compiled a list of [3 recommended free Python books](https://blog.rmotr.com/the-3-python-books-you-need-to-get-started-for-free-9b72a2c6fb17) to get started.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
